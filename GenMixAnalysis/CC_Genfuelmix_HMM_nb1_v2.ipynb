# %% [markdown]
# Try to use an HMM on Nuclear generation data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import random
import pylab
from collections import Counter
import time

# %%
from sklearn.model_selection import train_test_split

# %%
import pickle

# %%
with open("HMM_1_GenFuelMix.pkl", "rb") as file: HMM_1_GenFuelMix = pickle.load(file)

# %%
readcsv_GenMix_2018_2022=pd.read_csv(r"..\ImportData\GenMix_2018_2022.csv")

# %%
GenMix_nanremoved = pd.read_pickle('GenMix_nanremoved.pkl')

# %%
GenMix_Consolidated = pd.read_pickle('GenMix_Consolidated.pkl')

# %% [markdown]
# The HMM lab functions would not be appropriate because the fitting is done by estimating known transition probabilities, and the observations are also discrete, not Gaussian.

# %% [markdown]
# HMM python libraries:
#
# hmmlearn 0.2.8\
# https://hmmlearn.readthedocs.io/en/latest/  \
# https://hmmlearn.readthedocs.io/en/latest/tutorial.html
# https://hmmlearn.readthedocs.io/en/latest/api.html#hmmlearn.hmm.GaussianHMM

# %%
import sys
# !{sys.executable} -m pip install hmmlearn
# Out:
# Collecting hmmlearn
#   Downloading hmmlearn-0.2.8-cp39-cp39-win_amd64.whl (110 kB)
#      -------------------------------------- 110.1/110.1 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.16 in c:\users\chen5\anaconda3\lib\site-packages (from hmmlearn) (1.0.2)
# Requirement already satisfied: numpy>=1.10 in c:\users\chen5\anaconda3\lib\site-packages (from hmmlearn) (1.21.5)
# Requirement already satisfied: scipy>=0.19 in c:\users\chen5\anaconda3\lib\site-packages (from hmmlearn) (1.9.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\chen5\anaconda3\lib\site-packages (from scikit-learn>=0.16->hmmlearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chen5\anaconda3\lib\site-packages (from scikit-learn>=0.16->hmmlearn) (2.2.0)
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.2.8
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\chen5\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\chen5\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\chen5\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\chen5\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\chen5\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\chen5\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\chen5\anaconda3\lib\site-packages)

# %%
from hmmlearn import hmm

# %% [markdown]
# ### Examine Nuclear data

# %%
Nuclear = GenMix_Consolidated["Nuclear Total"]

# %%
plt.plot(GenMix_Consolidated["Nuclear Total"])

# %% [markdown]
# Fundamentals:
#
# SPP has two nuclear plants:
# 1. Wolf Creek Generating Station in Kansas, 1200 MW.
# 2. Cooper Nuclear Station in Nebraska, 835 MW.
#
# https://en.wikipedia.org/wiki/Cooper_Nuclear_Station \
# https://en.wikipedia.org/wiki/Wolf_Creek_Generating_Station \
# Looked at nuclear plant map
# https://www.nppd.com/powering-nebraska/energy-resources/nuclear?locale=en

# %% [markdown]
# maybe can be modeled with 7-10 states?

# %%
nuclear_train, nuclear_test = train_test_split(Nuclear,train_size = .5,shuffle= False)

# %%
plt.plot(nuclear_train)

# %%
plt.hist(nuclear_train,1000)
plt.show()

# %%
plt.hist(nuclear_train[np.logical_and(nuclear_train>1180,nuclear_train<1250)],1000)
plt.show()

# %% [markdown]
# ### HMM 1

# %%
model = hmm.GaussianHMM(n_components=7, n_iter=100)

# %%
nuclear_train.values.reshape(-1, 1)
# Out:
# array([[2033.8, 2034.4, 2034. , ..., 2033.4, 2033.7, 2032.8]])

# %%
X = nuclear_train.values.reshape(-1, 1)

# %%
model.fit(nuclear_train.values.reshape(-1, 1))
# Out:
# GaussianHMM(n_components=7, n_iter=100)

# %%
# takes a minute

# %%
Z2 = model.predict(X)

# %%
plt.plot(Z2)

# %%
plt.hist(Z2,7)
# Out:
# (array([12354., 12356.,  7163., 63076., 73573., 23011.,  7160.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.plot(Z2,X,".")

# %%
plt.plot(nuclear_train)

# %%
vars(model)
# Out:
# {'n_components': 7,
#  'params': 'stmc',
#  'init_params': 'stmc',
#  'startprob_prior': 1.0,
#  'transmat_prior': 1.0,
#  'algorithm': 'viterbi',
#  'random_state': None,
#  'n_iter': 100,
#  'tol': 0.01,
#  'verbose': False,
#  'implementation': 'log',
#  'monitor_': ConvergenceMonitor(
#      history=[-1516768.6838275902, -1360848.8198591555, -1149573.4950930986, -1105198.6919494744, -1088508.886255946, -1060392.7455423188, -1019236.9289396818, -941623.8705686126, -914834.3399547334, -871529.8777680709, -822710.5344904981, -789448.4536185559, -781978.8513009723, -779456.4007323527, -778321.9001745002, -776724.3047184179, -774647.9748111336, -773248.9529556329, -772634.3593178502, -771704.26404317, -771057.3765493317, -770997.4079003095, -770995.7926847745, -770995.6807982968, -770995.6692817693, -770995.6675226804],
#      iter=26,
#      n_iter=100,
#      tol=0.01,
#      verbose=False,
#  ),
#  'covariance_type': 'diag',
#  'min_covar': 0.001,
#  'means_prior': 0,
#  'means_weight': 0,
#  'covars_prior': 0.01,
#  'covars_weight': 1,
#  'n_features': 1,
#  'startprob_': array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 1.24237048e-110,
#         1.00000000e+000, 2.43594493e-250, 0.00000000e+000]),
#  'transmat_': array([[2.31715170e-04, 9.98952369e-01, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 8.15915524e-04, 0.00000000e+00],
#         [9.64846916e-01, 3.51530844e-02, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 1.46606434e-11, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 3.90049956e-03, 0.00000000e+00,
#          0.00000000e+00, 6.99757962e-04, 9.95399742e-01],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.98584874e-01,
#          8.21970705e-04, 5.93155361e-04, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.74660485e-04,
#          9.99295655e-01, 2.96850078e-05, 0.00000000e+00],
#         [3.34344545e-10, 4.30973536e-04, 1.73121810e-04, 1.72358673e-03,
#          2.94019077e-84, 9.97627697e-01, 4.46204405e-05],
#         [0.00000000e+00, 0.00000000e+00, 9.91578762e-01, 0.00000000e+00,
#          0.00000000e+00, 1.80136419e-07, 8.42105810e-03]]),
#  'means_': array([[1218.63278839],
#         [1218.63135177],
#         [ 804.13858204],
#         [1976.7494716 ],
#         [2031.34154129],
#         [1745.5557221 ],
#         [ 804.14109165]]),
#  '_covars_': array([[1.24916252e+01],
#         [1.24884921e+01],
#         [1.29362904e+01],
#         [5.15097165e+02],
#         [2.23583994e+01],
#         [6.22122797e+04],
#         [1.28218725e+01]])}

# %%
plt.hist(model.means_)
# Out:
# (array([2., 0., 0., 2., 0., 0., 0., 1., 0., 2.]),
#  array([ 804.13858204,  926.85887797, 1049.57917389, 1172.29946982,
#         1295.01976574, 1417.74006167, 1540.46035759, 1663.18065352,
#         1785.90094944, 1908.62124537, 2031.34154129]),
#  <BarContainer object of 10 artists>)

# %%
plt.imshow(model.transmat_, cmap='hot', interpolation='nearest')

# %% [markdown]
# Two of the states are redundant/equivalent to other states. Train with 5 latent states next

# %%
with open("HMM_1_GenFuelMix.pkl", "wb") as file: pickle.dump(model, file)

# %%
with open("HMM_1_GenFuelMix.pkl", "rb") as file: HMM_1_GenFuelMix = pickle.load(file)

# %%
HMM_1_GenFuelMix
# Out:
# GaussianHMM(n_components=7, n_iter=100)

# %%
model
# Out:
# GaussianHMM(n_components=7, n_iter=100)

# %% [markdown]
# Fundamentals:
#
# SPP has two nuclear plants:
# 1. Wolf Creek Generating Station in Kansas, 1200 MW.
# 2. Cooper Nuclear Station in Nebraska, 835 MW.
#
# https://en.wikipedia.org/wiki/Cooper_Nuclear_Station \
# https://en.wikipedia.org/wiki/Wolf_Creek_Generating_Station \
# Looked at nuclear plant map
# https://www.nppd.com/powering-nebraska/energy-resources/nuclear?locale=en

# %% [markdown]
# Sample

# %%
X, Z = model.sample(len(nuclear_train))

# %%
Xsamp = X
Zsamp = Z

# %%
plt.plot(Xsamp)

# %%
plt.plot(Zsamp)

# %%
plt.plot(Xsamp[:25000])

# %%
plt.plot(Zsamp[:25000])

# %%
plt.plot(Zsamp,Xsamp,".")

# %% [markdown]
# State 5 takes in a lot more variance than expect

# %% [markdown]
# ### HMM 2

# %%
model2 = hmm.GaussianHMM(n_components=5, n_iter=100)

# %%
nuclear_train.values.reshape(-1, 1)
# Out:
# array([[2033.8, 2034.4, 2034. , ..., 2033.4, 2033.7, 2032.8]])

# %%
Xtrain = nuclear_train.values.reshape(-1, 1)

# %%
X = nuclear_train.values.reshape(-1, 1)

# %%
import time
start = time.process_time()
# your code here    
print(time.process_time() - start)
# Out:
# 0.0

# %%
start = time.process_time()

model2.fit(Xtrain)

print(time.process_time() - start)
# Out:
# 40.265625

# %%
# takes 40s

# %%
Zpredict = model2.predict(Xtrain)

# %%
plt.plot(Zpredict)

# %%
plt.plot(nuclear_train)

# %%
plt.hist(Zpredict,5)
# Out:
# (array([73545., 23408., 23446., 39134., 39160.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.plot(Zpredict,Xtrain,".")

# %%
vars(model2)
# Out:
# {'n_components': 5,
#  'params': 'stmc',
#  'init_params': 'stmc',
#  'startprob_prior': 1.0,
#  'transmat_prior': 1.0,
#  'algorithm': 'viterbi',
#  'random_state': None,
#  'n_iter': 100,
#  'tol': 0.01,
#  'verbose': False,
#  'implementation': 'log',
#  'monitor_': ConvergenceMonitor(
#      history=[-1501596.9969220534, -1255366.1483291546, -1129592.9641633627, -1124694.4593723656, -1123954.3313172502, -1123444.7411740306, -1122561.9658235426, -1121132.4360677798, -1119226.5847080732, -1117301.373158806, -1115753.5938060055, -1114593.6268745796, -1113634.8258859648, -1112612.049089956, -1111072.9765488748, -1107970.4249937106, -1100204.622952129, -1077170.9947165218, -1016346.0118768421, -959077.4752600072, -949588.1515152914, -948772.3657057608, -948403.0157202918, -948274.4408937552, -948257.8407277843, -948253.8674647379, -948253.1862084398, -948253.1187709129, -948253.1127580763],
#      iter=29,
#      n_iter=100,
#      tol=0.01,
#      verbose=False,
#  ),
#  'covariance_type': 'diag',
#  'min_covar': 0.001,
#  'means_prior': 0,
#  'means_weight': 0,
#  'covars_prior': 0.01,
#  'covars_weight': 1,
#  'n_features': 1,
#  'startprob_': array([1.00000000e+000, 0.00000000e+000, 1.92231889e-248, 3.01565382e-072,
#         1.97444814e-047]),
#  'transmat_': array([[9.99290040e-001, 2.49712879e-027, 1.01231718e-020,
#          5.95296549e-009, 7.09953610e-004],
#         [3.76896839e-179, 1.60841265e-004, 9.99839159e-001,
#          4.62278221e-011, 6.35660408e-022],
#         [1.56216193e-135, 5.23944164e-001, 4.75015124e-001,
#          1.04071210e-003, 2.66866959e-018],
#         [1.51400264e-013, 2.95363852e-007, 9.58517819e-004,
#          5.37720091e-003, 9.93663986e-001],
#         [1.15434069e-003, 4.20388842e-018, 1.14254725e-012,
#          7.35211996e-001, 2.63633663e-001]]),
#  'means_': array([[2031.38430572],
#         [1132.3359392 ],
#         [1133.90083831],
#         [1959.95194073],
#         [1960.25851446]]),
#  '_covars_': array([[2.19179974e+01],
#         [6.55585685e+04],
#         [6.63913338e+04],
#         [1.70930851e+03],
#         [1.68825135e+03]])}

# %%
plt.imshow(model2.transmat_, cmap='hot', interpolation='nearest')

# %%
# generally not great, high variances

# %%
with open("HMM_2_5states_GenFuelMix.pkl", "wb") as file: pickle.dump(model2, file)

# %% [markdown]
# ### HMM 3
# 6 states

# %%
model3 = hmm.GaussianHMM(n_components=6, n_iter=100)

# %%
Xtrain = nuclear_train.values.reshape(-1, 1)

# %%
X = nuclear_train.values.reshape(-1, 1)

# %%
start = time.process_time()

model3.fit(Xtrain)

print(time.process_time() - start)
# Out:
# 50.15625

# %%
# takes 50s

# %%
Zpredict = model3.predict(Xtrain)

# %%
plt.plot(Zpredict)

# %%
plt.plot(nuclear_train)

# %%
plt.hist(Zpredict,6)
# Out:
# (array([ 4466., 11166., 11194., 68135., 35559., 68173.]),
#  array([0.        , 0.83333333, 1.66666667, 2.5       , 3.33333333,
#         4.16666667, 5.        ]),
#  <BarContainer object of 6 artists>)

# %%
plt.plot(Zpredict,Xtrain,".")

# %%
vars(model3)
# Out:
# {'n_components': 6,
#  'params': 'stmc',
#  'init_params': 'stmc',
#  'startprob_prior': 1.0,
#  'transmat_prior': 1.0,
#  'algorithm': 'viterbi',
#  'random_state': None,
#  'n_iter': 100,
#  'tol': 0.01,
#  'verbose': False,
#  'implementation': 'log',
#  'monitor_': ConvergenceMonitor(
#      history=[-1453236.8776409968, -1268444.6590913406, -1142723.6871099006, -1126548.0795971465, -1124302.9685112184, -1121783.7032181153, -1109408.0708317717, -1086115.645051543, -1073047.787558099, -1054549.6620381277, -1024878.8107255552, -1022732.0617024521, -1021006.8541774855, -1019211.1618964876, -1018548.0234816545, -1017585.0209112568, -1016898.5049460166, -1016812.9130211803, -1016807.0350849617, -1013903.8520385528, -1008089.9967294402, -1005420.6414375058, -1004938.2875839436, -1004906.7718387643, -1004890.8048066002, -1004890.6624054826, -1004890.6596693232],
#      iter=27,
#      n_iter=100,
#      tol=0.01,
#      verbose=False,
#  ),
#  'covariance_type': 'diag',
#  'min_covar': 0.001,
#  'means_prior': 0,
#  'means_weight': 0,
#  'covars_prior': 0.01,
#  'covars_weight': 1,
#  'n_features': 1,
#  'startprob_': array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 9.99999994e-001,
#         1.40501430e-128, 6.06597089e-009]),
#  'transmat_': array([[9.92898933e-01, 1.64272494e-04, 6.23682723e-03, 0.00000000e+00,
#          6.99966812e-04, 0.00000000e+00],
#         [7.53484487e-10, 1.79447038e-01, 8.20444625e-01, 0.00000000e+00,
#          1.08335987e-04, 0.00000000e+00],
#         [2.61938025e-03, 9.97006507e-01, 3.96887940e-07, 0.00000000e+00,
#          3.73715748e-04, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.29546557e-01,
#          3.25104458e-06, 7.70450192e-01],
#         [1.48089340e-04, 7.78919912e-13, 8.50899035e-05, 1.41329374e-10,
#          9.98681011e-01, 1.08580989e-03],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.82903248e-01,
#          6.33901719e-04, 1.64628504e-02]]),
#  'means_': array([[1204.94473612],
#         [1219.39513578],
#         [1219.38384253],
#         [2006.23391034],
#         [1396.57546967],
#         [2006.16005448]]),
#  '_covars_': array([[6.00039512e+01],
#         [7.16006404e+00],
#         [7.18168215e+00],
#         [9.84964351e+02],
#         [2.60721146e+05],
#         [9.89366344e+02]])}

# %%
plt.imshow(model3.transmat_, cmap='hot', interpolation='nearest')

# %%
# generally not great, high variances

# %%
with open("HMM_3_6states_GenFuelMix.pkl", "wb") as file: pickle.dump(model3, file)

# %% [markdown]
# ### model comparison

# %% [markdown]
# Likelihood

# %%
model.score(X)
# Out:
# -770995.6669358049

# %%
model2.score(X)
# Out:
# -948253.1120031378

# %%
model3.score(X)
# Out:
# -1004890.65952904

# %% [markdown]
# first model best on likelihood

# %% [markdown]
# 12/12: keep trying

# %%
nuclear_train, nuclear_test, date_train, date_test = train_test_split(Nuclear,GenMix_Consolidated['datetime'],train_size = .5,shuffle= False)

# %%
diff_time = GenMix_Consolidated["datetime"].diff()

# %%
GenMix_Consolidated_gaps = GenMix_Consolidated[diff_time!= diff_time[100]]

# %%
diff_time[1:][diff_time> 2*diff_time[100]].sort_values().tail(10)
# Out:
# 303285   0 days 02:10:00
# 52547    0 days 02:15:00
# 463275   0 days 02:15:00
# 18550    0 days 02:25:00
# 374084   0 days 02:40:00
# 66909    0 days 02:40:00
# 405533   0 days 02:55:00
# 156504   0 days 03:25:00
# 463352   0 days 04:40:00
# 130054   0 days 09:05:00
# Name: datetime, dtype: timedelta64[ns]

# %%
fig, ax = plt.subplots()
plt.plot(date_train,nuclear_train)
ax.set_title("Nuclear Generation in MW")
# Out:
# Text(0.5, 1.0, 'Nuclear Generation in MW')

# %%
plt.hist(nuclear_train,500)
plt.show()

# %%
model = hmm.GaussianHMM(n_components=7, n_iter=10,random_state = 7969)

# %%
X = nuclear_train.values.reshape(-1, 1)

# %%
import time

# %%
t0 = time.time()

model.fit(nuclear_train.values.reshape(-1, 1))

print(time.time()-t0)
# Out:
# 17.88148283958435

# %%
# 8:49 takes a while now?
72 seconds

# %%
model.score(X)
# Out:
# -977597.9197827892

# %%
Z2 = model.predict(X)

# %%
plt.hist(Z2,7)
# Out:
# (array([68282., 27720.,  3260., 15411., 10828., 68315., 57256.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.plot(Z2,X,".")

# %%
vars(model)
# Out:
# {'n_components': 7,
#  'params': 'stmc',
#  'init_params': 'stmc',
#  'startprob_prior': 1.0,
#  'transmat_prior': 1.0,
#  'algorithm': 'viterbi',
#  'random_state': None,
#  'n_iter': 5,
#  'tol': 0.01,
#  'verbose': False,
#  'implementation': 'log',
#  'monitor_': ConvergenceMonitor(
#      history=[-1882496.518704792, -1640146.6359867495, -1353406.8837315799, -1308237.0359656203, -1288226.3211458055],
#      iter=5,
#      n_iter=5,
#      tol=0.01,
#      verbose=False,
#  ),
#  'covariance_type': 'diag',
#  'min_covar': 0.001,
#  'means_prior': 0,
#  'means_weight': 0,
#  'covars_prior': 0.01,
#  'covars_weight': 1,
#  'n_features': 1,
#  'startprob_': array([3.48208260e-07, 4.57101155e-22, 1.71514231e-48, 1.35956876e-19,
#         9.95238382e-01, 4.76126956e-03, 8.38440272e-18]),
#  'transmat_': array([[8.34489610e-01, 2.03301997e-07, 2.41736299e-29, 1.25161851e-06,
#          1.62652995e-01, 2.65087840e-03, 2.05061224e-04],
#         [1.46787423e-07, 3.00905505e-02, 2.56842459e-05, 8.64733210e-06,
#          1.44516109e-11, 1.11287586e-07, 9.69874860e-01],
#         [2.50686758e-30, 1.28231781e-04, 9.99870378e-01, 2.36900160e-09,
#          1.10001676e-36, 2.58501359e-28, 1.38806672e-06],
#         [1.92456188e-07, 9.54149623e-01, 9.51271308e-04, 3.38974528e-05,
#          1.24578730e-09, 6.12855381e-03, 3.87364612e-02],
#         [7.90720053e-01, 1.41702431e-10, 1.73824402e-29, 3.26641353e-07,
#          2.09054028e-01, 2.23415363e-04, 2.17722690e-06],
#         [9.65364200e-01, 4.31412627e-04, 1.12988354e-21, 1.23185949e-06,
#          4.05218308e-04, 3.16819896e-02, 2.11594808e-03],
#         [8.33311211e-15, 6.49559847e-03, 1.66888066e-04, 9.93060437e-01,
#          2.93538038e-09, 2.76742841e-04, 3.30606589e-07]]),
#  'means_': array([[2015.12034699],
#         [1850.29531262],
#         [ 969.80416743],
#         [1851.04976268],
#         [2017.44613842],
#         [1990.62106162],
#         [1851.03226038]]),
#  '_covars_': array([[  605.23140656],
#         [16614.47108515],
#         [41208.20705077],
#         [16514.76409346],
#         [  537.52179143],
#         [  876.65353993],
#         [16545.48896206]])}

# %%
np.log(model.transmat_+.1)
# Out:
# array([[-1.93216604, -2.30258509, -2.30258509, -2.30258509, -2.30151275,
#          0.05359627, -2.30258499],
#        [-2.30258509,  0.09511294, -2.30041803, -2.30258509, -2.30258509,
#         -2.30258509, -2.30258509],
#        [-2.30258509, -2.27740038,  0.08995393, -2.30258509, -2.26986944,
#         -2.30258509, -2.30258509],
#        [-2.30258509, -2.30258509, -2.30019216,  0.09492059, -2.30069798,
#         -2.30258509, -2.30258509],
#        [-2.30258509, -2.30258075, -2.29841647, -2.29571029,  0.0913954 ,
#         -2.30258509, -2.27118505],
#        [ 0.09499245, -2.30258509, -2.30258509, -2.30258509, -2.30258476,
#         -2.30258501, -2.29909716],
#        [-2.30258494, -2.30258509, -2.30258509, -2.30258509, -2.29754599,
#         -2.29509873,  0.09416712]])

# %%
plt.matshow(np.log(model.transmat_+.0001));
plt.colorbar()
plt.show()

# %%
plt.matshow((model.transmat_));
plt.colorbar()
plt.show()

# %%
plt.matshow(np.log(model.transmat_+1));
plt.colorbar()
plt.show()

# %%
plt.imshow(model.transmat_, cmap='hot', interpolation='nearest')

# %% [markdown]
# Two of the states are redundant/equivalent to other states. Train with 5 latent states next

# %%
plt.plot(Z2,marker = '.',linestyle="None")

# %%
len(nuclear_train)

# %%
X, Z = model.sample(len(nuclear_train))

# %%
Xsamp = X
Zsamp = Z

# %%
plt.plot(Xsamp)

# %%
plt.plot(Zsamp)

# %%
plt.plot(Xsamp[:25000])

# %%
plt.plot(Zsamp[:25000])

# %%
plt.plot(Zsamp,Xsamp,".")

# %%
model
# Out:
# GaussianHMM(n_components=7, n_iter=60, random_state=7969)

# %%
max_score = model.score(X)
best_model = model

# %%
9//4
# Out:
# 2

# %%
t0 = time.time()
for i in range(10):
    model = hmm.GaussianHMM(n_components=7+i//4, n_iter=40-i*3,random_state = 7969+i)
    model.fit(nuclear_train.values.reshape(-1, 1))

    print(time.time()-t0)
    if model.score(X) > max_score:
        max_score = model.score(X)
        best_model = model
# Out:
# 57.159600019454956
# 117.50313425064087
# 173.8690276145935
# 218.39509868621826
# 264.82974576950073
# 308.02889943122864
# 347.8242115974426
# 382.51972699165344
# 424.9591450691223
# 466.59375977516174

# %%
max_score
# Out:
# -812388.7887550885

# %%
best_model
# Out:
# GaussianHMM(n_components=7, n_iter=31, random_state=7972)

# %%
model = best_model

# %%
with open("HMM_best_GenFuelMix12_12.pkl", "wb") as file: pickle.dump(best_model, file)

# %%
Z2 = model.predict(X)

# %%
model.means_.flatten()
# Out:
# array([1467.02195604, 1920.08492997,  805.95204388, 2023.71296318,
#        2035.09892362, 1218.81158516, 1982.22941618])

# %%
model_means = means model.means_
# Out:
# array([[1467.02195604],
#        [1920.08492997],
#        [ 805.95204388],
#        [2023.71296318],
#        [2035.09892362],
#        [1218.81158516],
#        [1982.22941618]])

# %%
pred_mean = model.means_[Z2]

# %%
pred_mean-pred_std
# Out:
# array([[2032.64621632],
#        [2032.64621632],
#        [2032.64621632],
#        ...,
#        [2018.32025168],
#        [2018.32025168],
#        [2018.32025168]])

# %%
pred_std = np.sqrt(model._covars_)[Z2]

# %%
x_range = np.arange(len(pred_mean))

# %%
np.sqrt(np.mean(np.square(pred_mean.flatten()-nuclear_train)))
# Out:
# 46.97646793046818

# %%
np.sqrt(np.mean(np.square(nuclear_train.diff())))
# Out:
# 2.5586913051948876

# %%
# Plot the confidence interval
plt.plot(x_range,nuclear_train,label = "true")
plt.plot(x_range, pred_mean, label = 'predicted latent mean')
plt.fill_between(x_range, (pred_mean-pred_std).flatten(), (pred_mean+pred_std).flatten(), color='red', alpha=0.2)

plt.legend()
plt.xlim(43000,51000)
plt.ylim(1120,2100)
plt.show()

# %%
pred_std
# Out:
# array([[2.4527073],
#        [2.4527073],
#        [2.4527073],
#        ...,
#        [5.3927115],
#        [5.3927115],
#        [5.3927115]])

# %%
Z2
# Out:
# array([4, 4, 4, ..., 3, 3, 3], dtype=int64)

# %%
plt.hist(Z2,7)
# Out:
# (array([ 7363., 12778., 27720., 50282., 79961., 15411., 57557.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.plot(Z2,X,".")

# %%
vars(model)
# Out:
# {'n_components': 7,
#  'params': 'stmc',
#  'init_params': 'stmc',
#  'startprob_prior': 1.0,
#  'transmat_prior': 1.0,
#  'algorithm': 'viterbi',
#  'random_state': 7972,
#  'n_iter': 31,
#  'tol': 0.01,
#  'verbose': False,
#  'implementation': 'log',
#  'monitor_': ConvergenceMonitor(
#      history=[-1811085.2338641402, -1423845.6955395036, -1314511.8248984867, -1252496.6322377766, -1169761.8885900886, -1108673.420950329, -1039805.8449937173, -974439.6678801703, -922353.2630434223, -901150.5217115922, -864271.1198069946, -851538.3475390808, -843772.2004667454, -837830.7505589775, -834516.1529645156, -832651.0941577228, -831713.8344422318, -831050.9332544372, -830249.0753129567, -829134.540959471, -827907.6305830505, -826050.8236975848, -821162.5572901374, -815848.5787890864, -813427.7224757449, -812794.7874212747, -812531.8851105612, -812441.9951112363, -812411.0384963701, -812402.6754216865, -812396.7770359768],
#      iter=31,
#      n_iter=31,
#      tol=0.01,
#      verbose=False,
#  ),
#  'covariance_type': 'diag',
#  'min_covar': 0.001,
#  'means_prior': 0,
#  'means_weight': 0,
#  'covars_prior': 0.01,
#  'covars_weight': 1,
#  'n_features': 1,
#  'startprob_': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00669027e-92,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00]),
#  'transmat_': array([[9.94946211e-001, 3.56047249e-003, 6.78065492e-004,
#          1.50294201e-142, 2.40222170e-198, 8.15251001e-004,
#          1.71554985e-143],
#         [2.05484766e-003, 9.95027487e-001, 0.00000000e+000,
#          6.67422474e-010, 3.20942328e-061, 0.00000000e+000,
#          2.91766454e-003],
#         [1.80380577e-004, 0.00000000e+000, 9.99819619e-001,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000],
#         [2.96173864e-118, 1.55159851e-004, 0.00000000e+000,
#          9.94808288e-001, 4.31399641e-003, 0.00000000e+000,
#          7.22556010e-004],
#         [8.90864181e-125, 1.39969159e-005, 0.00000000e+000,
#          2.71686583e-003, 9.97269137e-001, 0.00000000e+000,
#          5.48501695e-031],
#         [3.90114363e-004, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 9.99609886e-001,
#          0.00000000e+000],
#         [1.11393959e-106, 4.92993702e-004, 0.00000000e+000,
#          7.88310601e-004, 1.54433993e-054, 0.00000000e+000,
#          9.98718696e-001]]),
#  'means_': array([[1467.02195604],
#         [1920.08492997],
#         [ 805.95204388],
#         [2023.71296318],
#         [2035.09892362],
#         [1218.81158516],
#         [1982.22941618]]),
#  '_covars_': array([[7.24769285e+04],
#         [7.72256242e+02],
#         [3.44339996e+01],
#         [2.90813374e+01],
#         [6.01577310e+00],
#         [1.17422709e+01],
#         [1.49648971e+02]])}

# %% [markdown]
# Forecast:

# %%
Z2[-1]
# Out:
# 3

# %%
state = np.zeros(model.n_components)

# %%
state[Z2[-1]] = 1

# %%
state.reshape(-1,1)
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.]])

# %%
np.linalg.matrix_power
# Out:
# <function numpy.linalg.matrix_power(a, n)>

# %%
model.means_[np.argmax(np.linalg.matrix_power(model.transmat_,209999) @ state.reshape(-1,1))]
# Out:
# array([2035.09892362])

# %%
model.means_
# Out:
# array([[1467.02195604],
#        [1920.08492997],
#        [ 805.95204388],
#        [2023.71296318],
#        [2035.09892362],
#        [1218.81158516],
#        [1982.22941618]])

# %% [markdown]
# How to predict from HMM? Use Viterbi last most likely state, Get most likely next state, and use that state's mean.
#
# Long term forecast, apply transition matrix
#
# More distribution wise would get probabilities for last state, apply transition matrix, and get a Gaussian mixture model.

# %%
Z3 = model.predict_proba(X)

# %%
Z3[-1]
# Out:
# array([3.71498673e-13, 5.83309582e-08, 0.00000000e+00, 9.99996601e-01,
#        9.04199308e-11, 0.00000000e+00, 3.34093808e-06])

# %%
pred_hmm = []
for i in range(2000):
    pred_hmm.append(model.means_[np.argmax(np.linalg.matrix_power(model.transmat_,i) @ state.reshape(-1,1))])

# %%
plt.plot(pred_hmm)
